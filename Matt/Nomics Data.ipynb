# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import csv
import json
from pprint import pprint

from api import nom_api

# %%
base_url = "https://api.nomics.com/v1/"
ticker = "btc"
coin_list =["BTC","ETH","LTC","BNB","BCH"]

currency_url = (f"{base_url}currencies/ticker?key={nom_api}&ids=BTC,ETH,LTC,BNB,BCH")

response = requests.get(currency_url,verify = False).json()
print(json.dumps(response,indent = 4, sort_keys = True))

btc_vol_1d = float(response[0]["1d"]["volume"])
btc_vol_365d = float(response[0]["365d"]["volume"])


print(f"BTC 1d Volume is: {btc_vol_1d}")
print(f"BTC 365d Volume is: {btc_vol_365d}")
print(f"BTC 1 year volume change is: {btc_vol_365d - btc_vol_1d}")
#print()
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [
#     {
#         "1d": {
#             "market_cap_change": "3601826514.64",
#             "market_cap_change_pct": "0.0150",
#             "price_change": "193.74485126",
#             "price_change_pct": "0.0150",
#             "volume": "17746924629.47",
#             "volume_change": "-4968027781.32",
#             "volume_change_pct": "-0.2187"
#         },
#         "30d": {
#             "market_cap_change": "43433223457.96",
#             "market_cap_change_pct": "0.2176",
#             "price_change": "2328.68203132",
#             "price_change_pct": "0.2158",
#             "volume": "542995376546.59",
#             "volume_change": "-177662003385.61",
#             "volume_change_pct": "-0.2465"
#         },
#         "365d": {
#             "market_cap_change": "72466017501.87",
#             "market_cap_change_pct": "0.4247",
#             "price_change": "3649.22019455",
#             "price_change_pct": "0.3853",
#             "volume": "10793745219054.65",
#             "volume_change": "6935217032696.17",
#             "volume_change_pct": "1.7974"
#         },
#         "7d": {
#             "market_cap_change": "28329280131.37",
#             "market_cap_change_pct": "0.1319",
#             "price_change": "1525.45460378",
#             "price_change_pct": "0.1316",
#             "volume": "147378555610.68",
#             "volume_change": "19956216389.56",
#             "volume_change_pct": "0.1566"
#         },
#         "circulating_supply": "18525912",
#         "currency": "BTC",
#         "first_candle": "2011-08-18T00:00:00Z",
#         "first_order_book": "2017-01-06T00:00:00Z",
#         "first_trade": "2011-08-18T00:00:00Z",
#         "high": "19337.69352527",
#         "high_timestamp": "2017-12-16T00:00:00Z",
#         "id": "BTC",
#         "logo_url": "https://s3.us-east-2.amazonaws.com/nomics-api/static/images/currencies/btc.svg",
#         "market_cap": "243077333043",
#         "max_supply": "21000000",
#         "name": "Bitcoin",
#         "num_exchanges": "367",
#         "num_pairs": "40901",
#         "price": "13120.93747627",
#         "price_date": "2020-10-24T00:00:00Z",
#         "price_timestamp": "2020-10-24T19:24:00Z",
#         "rank": "1",
#         "rank_delta": "0",
#         "status": "active",
#         "symbol": "BTC",
#         "ytd": {
#             "market_cap_change": "104172374474.23",
#             "market_cap_change_pct": "0.7500",
#             "price_change": "5460.85020355",
#             "price_change_pct": "0.7129",
#             "volume": "9280889818988.64",
#             "volume_change": "4364785166328.49",
#             "volume_change_pct": "0.8879"
#         }
#     },
#     {
#         "1d": {
#             "market_cap_change": "453009158.15",
#             "market_cap_change_pct": "0.0098",
#             "price_change": "3.95341206",
#             "price_change_pct": "0.0097",
#             "volume": "7655827854.04",
#             "volume_change": "-2895479049.49",
#             "volume_change_pct": "-0.2744"
#         },
#         "30d": {
#             "market_cap_change": "7504409522.20",
#             "market_cap_change_pct": "0.1910",
#             "price_change": "65.08444090",
#             "price_change_pct": "0.1868",
#             "volume": "289969194239.87",
#             "volume_change": "-169699450956.39",
#             "volume_change_pct": "-0.3692"
#         },
#         "365d": {
#             "market_cap_change": "27495049118.90",
#             "market_cap_change_pct": "1.4250",
#             "price_change": "235.37856434",
#             "price_change_pct": "1.3211",
#             "volume": "4893225956072.61",
#             "volume_change": "3242995408930.31",
#             "volume_change_pct": "1.9652"
#         },
#         "7d": {
#             "market_cap_change": "4806295396.45",
#             "market_cap_change_pct": "0.1145",
#             "price_change": "42.16891117",
#             "price_change_pct": "0.1135",
#             "volume": "68340472463.93",
#             "volume_change": "350422784.71",
#             "volume_change_pct": "0.0052"
#         },
#         "circulating_supply": "113141680",
#         "currency": "ETH",
#         "first_candle": "2015-08-07T00:00:00Z",
#         "first_order_book": "2018-08-29T00:00:00Z",
#         "first_trade": "2015-08-07T00:00:00Z",
#         "high": "1391.34818411",
#         "high_timestamp": "2018-01-13T00:00:00Z",
#         "id": "ETH",
#         "logo_url": "https://s3.us-east-2.amazonaws.com/nomics-api/static/images/currencies/eth.svg",
#         "market_cap": "46789843522",
#         "max_supply": "113141680",
#         "name": "Ethereum",
#         "num_exchanges": "361",
#         "num_pairs": "25776",
#         "price": "413.55089893",
#         "price_date": "2020-10-24T00:00:00Z",
#         "price_timestamp": "2020-10-24T19:24:00Z",
#         "rank": "2",
#         "rank_delta": "0",
#         "status": "active",
#         "symbol": "ETH",
#         "ytd": {
#             "market_cap_change": "31369277207.40",
#             "market_cap_change_pct": "2.0342",
#             "price_change": "272.19942745",
#             "price_change_pct": "1.9257",
#             "volume": "4311869462327.40",
#             "volume_change": "2309555658514.25",
#             "volume_change_pct": "1.1534"
#         }
#     },
#     {
#         "1d": {
#             "market_cap_change": "89836830.83",
#             "market_cap_change_pct": "0.0179",
#             "price_change": "4.82872607",
#             "price_change_pct": "0.0179",
#             "volume": "2088159810.88",
#             "volume_change": "-683799853.36",
#             "volume_change_pct": "-0.2467"
#         },
#         "30d": {
#             "market_cap_change": "1095892884.87",
#             "market_cap_change_pct": "0.2731",
#             "price_change": "58.75108576",
#             "price_change_pct": "0.2713",
#             "volume": "64558652030.28",
#             "volume_change": "-5239612908.74",
#             "volume_change_pct": "-0.0751"
#         },
#         "365d": {
#             "market_cap_change": "514877337.88",
#             "market_cap_change_pct": "0.1121",
#             "price_change": "21.22524362",
#             "price_change_pct": "0.0835",
#             "volume": "1120694749503.79",
#             "volume_change": "786936919105.94",
#             "volume_change_pct": "2.3578"
#         },
#         "7d": {
#             "market_cap_change": "511098712.01",
#             "market_cap_change_pct": "0.1112",
#             "price_change": "27.46372570",
#             "price_change_pct": "0.1108",
#             "volume": "16893064308.10",
#             "volume_change": "-1744558152.29",
#             "volume_change_pct": "-0.0936"
#         },
#         "circulating_supply": "18553546",
#         "currency": "BCH",
#         "first_candle": "2017-07-09T00:00:00Z",
#         "first_order_book": "2018-08-29T00:00:00Z",
#         "first_trade": "2017-07-27T00:00:00Z",
#         "high": "3716.88621242",
#         "high_timestamp": "2017-12-20T00:00:00Z",
#         "id": "BCH",
#         "logo_url": "https://s3.us-east-2.amazonaws.com/nomics-api/static/images/currencies/bch.svg",
#         "market_cap": "5108503823",
#         "max_supply": "21000000",
#         "name": "Bitcoin Cash",
#         "num_exchanges": "241",
#         "num_pairs": "1194",
#         "price": "275.33840976",
#         "price_date": "2020-10-24T00:00:00Z",
#         "price_timestamp": "2020-10-24T19:24:00Z",
#         "rank": "5",
#         "rank_delta": "0",
#         "status": "active",
#         "symbol": "BCH",
#         "ytd": {
#             "market_cap_change": "902564706.68",
#             "market_cap_change_pct": "0.2146",
#             "price_change": "44.21065666",
#             "price_change_pct": "0.1913",
#             "volume": "1010055100987.25",
#             "volume_change": "597197306372.94",
#             "volume_change_pct": "1.4465"
#         }
#     },
#     {
#         "1d": {
#             "market_cap_change": "40474533.95",
#             "market_cap_change_pct": "0.0090",
#             "price_change": "0.27369119",
#             "price_change_pct": "0.0090",
#             "volume": "278997157.63",
#             "volume_change": "-97796838.06",
#             "volume_change_pct": "-0.2595"
#         },
#         "30d": {
#             "market_cap_change": "913230234.42",
#             "market_cap_change_pct": "0.2522",
#             "price_change": "6.17531684",
#             "price_change_pct": "0.2522",
#             "volume": "12466432506.65",
#             "volume_change": "-2653657237.82",
#             "volume_change_pct": "-0.1755"
#         },
#         "365d": {
#             "market_cap_change": "1622869713.97",
#             "market_cap_change_pct": "0.5573",
#             "price_change": "11.94277669",
#             "price_change_pct": "0.6379",
#             "volume": "116854906130.05",
#             "volume_change": "48687270080.43",
#             "volume_change_pct": "0.7142"
#         },
#         "7d": {
#             "market_cap_change": "20195008.12",
#             "market_cap_change_pct": "0.0045",
#             "price_change": "0.13655984",
#             "price_change_pct": "0.0045",
#             "volume": "2572702959.88",
#             "volume_change": "-468290822.31",
#             "volume_change_pct": "-0.1540"
#         },
#         "circulating_supply": "147883948",
#         "currency": "BNB",
#         "first_candle": "2017-07-14T00:00:00Z",
#         "first_order_book": "2018-08-29T00:00:00Z",
#         "first_trade": "2017-07-14T00:00:00Z",
#         "high": "38.89018405",
#         "high_timestamp": "2019-06-21T00:00:00Z",
#         "id": "BNB",
#         "logo_url": "https://s3.us-east-2.amazonaws.com/nomics-api/static/images/currencies/bnb.svg",
#         "market_cap": "4534831844",
#         "max_supply": "179883948",
#         "name": "Binance Coin",
#         "num_exchanges": "100",
#         "num_pairs": "923",
#         "price": "30.66480105",
#         "price_date": "2020-10-24T00:00:00Z",
#         "price_timestamp": "2020-10-24T19:24:00Z",
#         "rank": "7",
#         "rank_delta": "0",
#         "status": "active",
#         "symbol": "BNB",
#         "ytd": {
#             "market_cap_change": "2281281403.00",
#             "market_cap_change_pct": "1.0123",
#             "price_change": "15.98128249",
#             "price_change_pct": "1.0884",
#             "volume": "102077455301.50",
#             "volume_change": "25384459090.73",
#             "volume_change_pct": "0.3310"
#         }
#     },
#     {
#         "1d": {
#             "market_cap_change": "206546489.80",
#             "market_cap_change_pct": "0.0563",
#             "price_change": "3.13600926",
#             "price_change_pct": "0.0562",
#             "volume": "1975648586.36",
#             "volume_change": "-78160977.04",
#             "volume_change_pct": "-0.0381"
#         },
#         "30d": {
#             "market_cap_change": "928920691.11",
#             "market_cap_change_pct": "0.3152",
#             "price_change": "13.98761166",
#             "price_change_pct": "0.3111",
#             "volume": "33858600650.42",
#             "volume_change": "-10074513758.97",
#             "volume_change_pct": "-0.2293"
#         },
#         "365d": {
#             "market_cap_change": "175963260.18",
#             "market_cap_change_pct": "0.0476",
#             "price_change": "0.73116173",
#             "price_change_pct": "0.0126",
#             "volume": "990186715841.01",
#             "volume_change": "420693986777.33",
#             "volume_change_pct": "0.7387"
#         },
#         "7d": {
#             "market_cap_change": "755832540.44",
#             "market_cap_change_pct": "0.2423",
#             "price_change": "11.46251245",
#             "price_change_pct": "0.2413",
#             "volume": "10810325069.70",
#             "volume_change": "3124331460.65",
#             "volume_change_pct": "0.4065"
#         },
#         "circulating_supply": "65737578",
#         "currency": "LTC",
#         "first_candle": "2013-03-25T00:00:00Z",
#         "first_order_book": "2018-08-29T00:00:00Z",
#         "first_trade": "2013-03-25T00:00:00Z",
#         "high": "356.42911459",
#         "high_timestamp": "2017-12-18T00:00:00Z",
#         "id": "LTC",
#         "logo_url": "https://s3.us-east-2.amazonaws.com/nomics-api/static/images/currencies/ltc.svg",
#         "market_cap": "3875658433",
#         "max_supply": "84000000",
#         "name": "Litecoin",
#         "num_exchanges": "296",
#         "num_pairs": "2014",
#         "price": "58.95651411",
#         "price_date": "2020-10-24T00:00:00Z",
#         "price_timestamp": "2020-10-24T19:24:00Z",
#         "rank": "9",
#         "rank_delta": "0",
#         "status": "active",
#         "symbol": "LTC",
#         "ytd": {
#             "market_cap_change": "989726495.91",
#             "market_cap_change_pct": "0.3429",
#             "price_change": "13.69167576",
#             "price_change_pct": "0.3025",
#             "volume": "838489832459.39",
#             "volume_change": "169636344147.42",
#             "volume_change_pct": "0.2536"
#         }
#     }
# ]
# BTC 1d Volume is: 17746924629.47
# BTC 365d Volume is: 10793745219054.65
# BTC 1 year volume change is: 10775998294425.18

# %%
vol=[]
price = []
volume = []
coin_id=[]
price_pct=[]

url = (f"{base_url}currencies/ticker?key={nom_api}&ids=")

for coins in coin_list:
    response = requests.get(url + coins, verify = False).json()
    coin_id.append(response[0]["currency"])
    price.append(response[0]["ytd"]["price_change"])
    vol.append(response[0]["ytd"]["volume"])
    price_pct.append(response[0]["ytd"]["price_change_pct"])
    #vol.append([response["1d"]["volume"]-response["365d"]["volume"]])
    
print(price)
print(coin_id)
print(vol)
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Applications/anaconda3/envs/PythonData/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Applications/anaconda3/envs/PythonData/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Applications/anaconda3/envs/PythonData/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ['5441.82866159', '271.68464743', '13.69139357', '15.98215047', '44.15612444']
# ['BTC', 'ETH', 'LTC', 'BNB', 'BCH']
# ['9280889818988.64', '4311869462327.40', '838489832459.39', '102077455301.50', '1010055100987.25']
# /Applications/anaconda3/envs/PythonData/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
coin_df = pd.DataFrame({
    "Ticker": coin_id,
    "YTD Price Change": price,
    "YTD Price Change %": price_pct,
    "YTD Volume":vol
})
coin_df
# Out:
#   Ticker YTD Price Change YTD Price Change %        YTD Volume
# 0    BTC    5441.82866159             0.7104  9280889818988.64
# 1    ETH     271.68464743             1.9221  4311869462327.40
# 2    LTC      13.69139357             0.3025   838489832459.39
# 3    BNB      15.98215047             1.0884   102077455301.50
# 4    BCH      44.15612444             0.1910  1010055100987.25

# %%
#coin_df.plot("Ticker","YTD Price Change %", kind = 'bar')
coin_df.dtypes
# Out:
# Ticker                object
# YTD Price Change      object
# YTD Price Change %    object
# YTD Volume            object
# dtype: object
